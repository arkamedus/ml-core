# %% [markdown]
# If you can get this notebook running, you should be able to run all other notebooks. If this can be done better using requirements.txt or something, it should.

# %%
#!pip install torch

# %%
import library.utils.general
from library.utils.general import *

# %%
get_device()

# %%
from library.utils.tokenization import TextVocabulary
vocab = TextVocabulary()
vocab.add_tokens([chr(i) for i in range(32, 127)]) #ascii
vocab.add_tokens([f"{i}" for i in range(0, 9)]) #integers
vocab.add_tokens(["True","False"])
vocab.token_map

# %%
vocab.tokenize("Hello World")

# %%
vocab.detokenize([46, 75, 82, 82, 85, 6, 61, 85, 88, 82, 74, 6, vocab.token_to_id("True")])
